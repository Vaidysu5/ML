# %%
import os
import numpy as np
import pandas as pd
import math
import matplotlib.pylab as plt
import seaborn as sns

# %matplotlib inline
sns.set(style='ticks', palette='Set2')

# %%
#Import data into Pandas as a data frame
df =pd.read_csv('./WBCD.csv')
df.head(20)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M        17.99         10.38          122.80     1001.0
# 1     842517         M        20.57         17.77          132.90     1326.0
# 2   84300903         M        19.69         21.25          130.00     1203.0
# 3   84348301         M        11.42         20.38           77.58      386.1
# 4   84358402         M        20.29         14.34          135.10     1297.0
# 5     843786         M        12.45         15.70           82.57      477.1
# 6     844359         M        18.25         19.98          119.60     1040.0
# 7   84458202         M        13.71         20.83           90.20      577.9
# 8     844981         M        13.00         21.82           87.50      519.8
# 9   84501001         M        12.46         24.04           83.97      475.9
# 10    845636         M        16.02         23.24          102.70      797.8
# 11  84610002         M        15.78         17.89          103.60      781.0
# 12    846226         M        19.17         24.80          132.40     1123.0
# 13    846381         M        15.85         23.95          103.70      782.7
# 14  84667401         M        13.73         22.61           93.60      578.3
# 15  84799002         M        14.54         27.54           96.73      658.8
# 16    848406         M        14.68         20.13           94.74      684.5
# 17  84862001         M        16.13         20.68          108.10      798.8
# 18    849014         M        19.81         22.15          130.00     1260.0
# 19   8510426         B        13.54         14.36           87.46      566.3
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.11840           0.27760         0.30010              0.14710
# 1           0.08474           0.07864         0.08690              0.07017
# 2           0.10960           0.15990         0.19740              0.12790
# 3           0.14250           0.28390         0.24140              0.10520
# 4           0.10030           0.13280         0.19800              0.10430
# 5           0.12780           0.17000         0.15780              0.08089
# 6           0.09463           0.10900         0.11270              0.07400
# 7           0.11890           0.16450         0.09366              0.05985
# 8           0.12730           0.19320         0.18590              0.09353
# 9           0.11860           0.23960         0.22730              0.08543
# 10          0.08206           0.06669         0.03299              0.03323
# 11          0.09710           0.12920         0.09954              0.06606
# 12          0.09740           0.24580         0.20650              0.11180
# 13          0.08401           0.10020         0.09938              0.05364
# 14          0.11310           0.22930         0.21280              0.08025
# 15          0.11390           0.15950         0.16390              0.07364
# 16          0.09867           0.07200         0.07395              0.05259
# 17          0.11700           0.20220         0.17220              0.10280
# 18          0.09831           0.10270         0.14790              0.09498
# 19          0.09779           0.08129         0.06664              0.04781
#
#     ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0   ...         25.38          17.33           184.60      2019.0
# 1   ...         24.99          23.41           158.80      1956.0
# 2   ...         23.57          25.53           152.50      1709.0
# 3   ...         14.91          26.50            98.87       567.7
# 4   ...         22.54          16.67           152.20      1575.0
# 5   ...         15.47          23.75           103.40       741.6
# 6   ...         22.88          27.66           153.20      1606.0
# 7   ...         17.06          28.14           110.60       897.0
# 8   ...         15.49          30.73           106.20       739.3
# 9   ...         15.09          40.68            97.65       711.4
# 10  ...         19.19          33.88           123.80      1150.0
# 11  ...         20.42          27.28           136.50      1299.0
# 12  ...         20.96          29.94           151.70      1332.0
# 13  ...         16.84          27.66           112.00       876.5
# 14  ...         15.03          32.01           108.80       697.7
# 15  ...         17.46          37.13           124.10       943.2
# 16  ...         19.07          30.88           123.40      1138.0
# 17  ...         20.96          31.48           136.80      1315.0
# 18  ...         27.32          30.88           186.80      2398.0
# 19  ...         15.11          19.26            99.70       711.2
#
#     smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.1622             0.6656           0.7119
# 1             0.1238             0.1866           0.2416
# 2             0.1444             0.4245           0.4504
# 3             0.2098             0.8663           0.6869
# 4             0.1374             0.2050           0.4000
# 5             0.1791             0.5249           0.5355
# 6             0.1442             0.2576           0.3784
# 7             0.1654             0.3682           0.2678
# 8             0.1703             0.5401           0.5390
# 9             0.1853             1.0580           1.1050
# 10            0.1181             0.1551           0.1459
# 11            0.1396             0.5609           0.3965
# 12            0.1037             0.3903           0.3639
# 13            0.1131             0.1924           0.2322
# 14            0.1651             0.7725           0.6943
# 15            0.1678             0.6577           0.7026
# 16            0.1464             0.1871           0.2914
# 17            0.1789             0.4233           0.4784
# 18            0.1512             0.3150           0.5372
# 19            0.1440             0.1773           0.2390
#
#     concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.26540          0.4601                  0.11890
# 1                0.18600          0.2750                  0.08902
# 2                0.24300          0.3613                  0.08758
# 3                0.25750          0.6638                  0.17300
# 4                0.16250          0.2364                  0.07678
# 5                0.17410          0.3985                  0.12440
# 6                0.19320          0.3063                  0.08368
# 7                0.15560          0.3196                  0.11510
# 8                0.20600          0.4378                  0.10720
# 9                0.22100          0.4366                  0.20750
# 10               0.09975          0.2948                  0.08452
# 11               0.18100          0.3792                  0.10480
# 12               0.17670          0.3176                  0.10230
# 13               0.11190          0.2809                  0.06287
# 14               0.22080          0.3596                  0.14310
# 15               0.17120          0.4218                  0.13410
# 16               0.16090          0.3029                  0.08216
# 17               0.20730          0.3706                  0.11420
# 18               0.23880          0.2768                  0.07615
# 19               0.12880          0.2977                  0.07259
#
# [20 rows x 32 columns]

# %%
#Transform DIAGNOSIS column to a numeric variable
df["diagnosis2"] = (df.diagnosis == "M").astype(int)
#drop the diagnosis variable expressed as 'M' or 'B'
df = df.drop("diagnosis", axis="columns")
#Also, drop the ID variable as it should not be used for prediction
df = df.drop("id",axis="columns")
df.head(5)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  diagnosis2
# 0          0.4601                  0.11890           1
# 1          0.2750                  0.08902           1
# 2          0.3613                  0.08758           1
# 3          0.6638                  0.17300           1
# 4          0.2364                  0.07678           1
#
# [5 rows x 31 columns]

# %%
predictor_cols = df[["radius_mean", "texture_mean", "perimeter_mean", "area_mean", "smoothness_mean","compactness_mean","concavity_mean"]]
target_col = df["diagnosis2"]
predictor_cols[:10]
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
# 7        13.71         20.83           90.20      577.9          0.11890
# 8        13.00         21.82           87.50      519.8          0.12730
# 9        12.46         24.04           83.97      475.9          0.11860
#
#    compactness_mean  concavity_mean
# 0           0.27760         0.30010
# 1           0.07864         0.08690
# 2           0.15990         0.19740
# 3           0.28390         0.24140
# 4           0.13280         0.19800
# 5           0.17000         0.15780
# 6           0.10900         0.11270
# 7           0.16450         0.09366
# 8           0.19320         0.18590
# 9           0.23960         0.22730

# %%
from sklearn import linear_model
lin_model = linear_model.LogisticRegression(C=1, max_iter = 2000)
# Fit the Logistic regression model now
lin_model.fit(predictor_cols, target_col)
# Out:
# LogisticRegression(C=1, max_iter=2000)

# %%
from sklearn import metrics

print("Accuracy = %.3f" % (metrics.accuracy_score(lin_model.predict(predictor_cols), df.diagnosis2)))
# Out:
# Accuracy = 0.912

# %%
print(lin_model)
# Out:
# LogisticRegression(C=1, max_iter=2000)

# %%
# col_list = list(df.columns.values.tolist())
# print("Number of columns in data frame = ", len(df.columns))
count = 0
for col in predictor_cols:
    print(col," ", lin_model.coef_[0,count],"\n")
    count = count+1
    
print("FINALLY printing the Intercept for Logistic Regression = ", lin_model.intercept_)
# Out:
# radius_mean   -2.740502227566238
#
# texture_mean   0.22617480510582605
#
# perimeter_mean   0.6267112037854013
#
# area_mean   -0.004497173718890701
#
# smoothness_mean   0.6012830652217535
#
# compactness_mean   0.8250235702916825
#
# concavity_mean   1.3706377753817658
#
# FINALLY printing the Intercept for Logistic Regression =  [-21.39131367]

# %%
plt.plot(lin_model.coef_.T,'o',label = "C=1")
plt.xticks(range(df.shape[1]),rotation = 90)
plt.ylim(-2.5,2.5)
plt.xlabel ("Feature")
plt.ylabel ("Coefficient Magnitude")
plt.legend()

# %%
X_new1=[[15.54, 12.36, 95.46, 763.3, 0.10, 0.15, 0.08664]]
def Predict_for_new_patient(X_new):
    pred_val = lin_model.predict(X_new)
    print("Prediction for new value = ", pred_val)
    if(pred_val == 1):
        pred_valstr = "Malignant"
    elif(pred_val == 0):
            pred_valstr ="Benign"
        
    return(pred_valstr)
    
print("Predicted value for New Patient = ", Predict_for_new_patient(X_new1))
# Out:
# Prediction for new value =  [0]
# Predicted value for New Patient =  Benign
# C:\Users\18624\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
X_new2=[[6.981,13.43,143.5]]

print("Predicted value for New Patient = ", Predict_for_new_patient(X_new2))
# Out:
# Prediction for new value =  [1]
# Predicted value for New Patient =  Malignant
# C:\Users\18624\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print("Predicted probability of class 1 (diagnosis2 = 1) =", lin_model.predict_proba(X_new1) [:,1])
# Out:
# Predicted probability of class 1 (diagnosis2 = 1) = [0.01112465]
# C:\Users\18624\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print("Predicted probability of class 0 (diagnosis2 = 0) =", lin_model.predict_proba(X_new2) [:,1])
# Out:
# Predicted probability of class 0 (diagnosis2 = 0) = [1.]
# C:\Users\18624\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# Finally print the ODDS ratios for each of the independent variables
# The ODDS ratio os the increase in likelihood for a ONE unit increase in the independent variable
# The odds ratio is simply the exponent of the fitted coefficient
# col_list = list(df.columns.values.tolist())
count=0
for col in predictor_cols:
    print("ODDS Ratio for variable ", col,"= ", np.exp(lin_model.coef_[0,count]),"\n")
    count = count+1
# Out:
# ODDS Ratio for variable  radius_mean =  0.064537926027005
#
# ODDS Ratio for variable  texture_mean =  1.253794815858779
#
# ODDS Ratio for variable  perimeter_mean =  1.8714456438636262
#
# ODDS Ratio for variable  area_mean =  0.9955129234249641
#
# ODDS Ratio for variable  smoothness_mean =  1.824458198132197
#
# ODDS Ratio for variable  compactness_mean =  2.2819345505583915
#
# ODDS Ratio for variable  concavity_mean =  3.93786136579942
