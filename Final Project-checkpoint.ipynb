# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

# %%
df_BCancer =pd.read_excel("Masked data.xlsx")
df_BCancer.head(20)
# Out:
#       Name            Status Work Package Type          Work Package Subtype  \
# 0  Trial 1              Open    Clinical Study  Investigator Initiated Trial
# 1  Trial 2  Open: Reapproval    Clinical Study                Interventional
# 2  Trial 3              Open    Clinical Study                Interventional
# 3  Trial 4              Open    Clinical Study                Interventional
# 4  Trial 5        Terminated    Clinical Study                Interventional
# 5  Trial 6  Open: Reapproval    Clinical Study                Interventional
#
#         Clinical Study Type Clinical Study Phase  \
# 0    Research Collaboration            Phase III
# 1  Superiority Registration            Phase III
# 2                       NaN            Phase III
# 3                       NaN            Phase III
# 4                       NaN            Phase III
# 5                  Efficacy            Phase III
#
#   Interventional/ Non-Interventional  Low Intervention Trial  \
# ...
